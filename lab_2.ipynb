# %% [markdown]
# <a href="https://colab.research.google.com/github/Varsham7605/BIS_Lab/blob/main/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

CHROM_LENGTH = 5
POP_SIZE = 4
CROSS_RATE = 0.8
MUT_RATE = 0.1
GENERATIONS = 10

def fitness(x):
    return x**2

def encode(x):
    return format(x, f'0{CHROM_LENGTH}b')

def decode(b):
    return int(b, 2)

def gene_expression(chrom):
    return decode(chrom)

def roulette_selection(pop, fitnesses):
    total_fit = sum(fitnesses)
    pick = random.uniform(0, total_fit)
    current = 0
    for i, f in enumerate(fitnesses):
        current += f
        if current > pick:
            return pop[i]
    return pop[-1]

def crossover(p1, p2):
    if random.random() < CROSS_RATE:
        point = random.randint(1, CHROM_LENGTH - 1)
        c1 = p1[:point] + p2[point:]
        c2 = p2[:point] + p1[point:]
        return c1, c2
    return p1, p2

def mutate(chrom):
    chrom_list = list(chrom)
    for i in range(CHROM_LENGTH):
        if random.random() < MUT_RATE:
            chrom_list[i] = '1' if chrom_list[i] == '0' else '0'
    return ''.join(chrom_list)

def gene_expression_algorithm():
    population = [encode(x) for x in [12, 23, 5, 19]]
    print("Initial Population:", population, [decode(c) for c in population])

    for gen in range(1, GENERATIONS + 1):
        expressed = [gene_expression(c) for c in population]
        fitnesses = [fitness(x) for x in expressed]

        total_fit = sum(fitnesses)
        probs = [f / total_fit for f in fitnesses]
        expected = [p * POP_SIZE for p in probs]

        print(f"\nGeneration {gen}")
        for i in range(POP_SIZE):
            print(f"x={expressed[i]}, bin={population[i]}, fit={fitnesses[i]}, "
                  f"prob={probs[i]:.3f}, exp_count={expected[i]:.2f}")

        new_pop = []
        while len(new_pop) < POP_SIZE:
            p1 = roulette_selection(population, fitnesses)
            p2 = roulette_selection(population, fitnesses)
            c1, c2 = crossover(p1, p2)
            c1, c2 = mutate(c1), mutate(c2)
            new_pop.extend([c1, c2])

        population = new_pop[:POP_SIZE]

    expressed = [gene_expression(c) for c in population]
    fitnesses = [fitness(x) for x in expressed]
    best_idx = fitnesses.index(max(fitnesses))
    print("\nFinal Best Solution:", expressed[best_idx], population[best_idx], "fitness=", fitnesses[best_idx])

gene_expression_algorithm()
# Out:
# Initial Population: ['01100', '10111', '00101', '10011'] [12, 23, 5, 19]
#
# Generation 1
# x=12, bin=01100, fit=144, prob=0.136, exp_count=0.54
# x=23, bin=10111, fit=529, prob=0.500, exp_count=2.00
# x=5, bin=00101, fit=25, prob=0.024, exp_count=0.09
# x=19, bin=10011, fit=361, prob=0.341, exp_count=1.36
#
# Generation 2
# x=29, bin=11101, fit=841, prob=0.589, exp_count=2.36
# x=3, bin=00011, fit=9, prob=0.006, exp_count=0.03
# x=23, bin=10111, fit=529, prob=0.370, exp_count=1.48
# x=7, bin=00111, fit=49, prob=0.034, exp_count=0.14
#
# Generation 3
# x=13, bin=01101, fit=169, prob=0.088, exp_count=0.35
# x=28, bin=11100, fit=784, prob=0.408, exp_count=1.63
# x=23, bin=10111, fit=529, prob=0.275, exp_count=1.10
# x=21, bin=10101, fit=441, prob=0.229, exp_count=0.92
#
# Generation 4
# x=31, bin=11111, fit=961, prob=0.420, exp_count=1.68
# x=4, bin=00100, fit=16, prob=0.007, exp_count=0.03
# x=23, bin=10111, fit=529, prob=0.231, exp_count=0.92
# x=28, bin=11100, fit=784, prob=0.342, exp_count=1.37
#
# Generation 5
# x=20, bin=10100, fit=400, prob=0.149, exp_count=0.60
# x=31, bin=11111, fit=961, prob=0.358, exp_count=1.43
# x=19, bin=10011, fit=361, prob=0.135, exp_count=0.54
# x=31, bin=11111, fit=961, prob=0.358, exp_count=1.43
#
# Generation 6
# x=7, bin=00111, fit=49, prob=0.018, exp_count=0.07
# x=27, bin=11011, fit=729, prob=0.270, exp_count=1.08
# x=31, bin=11111, fit=961, prob=0.356, exp_count=1.42
# x=31, bin=11111, fit=961, prob=0.356, exp_count=1.42
#
# Generation 7
# x=29, bin=11101, fit=841, prob=0.226, exp_count=0.90
# x=31, bin=11111, fit=961, prob=0.258, exp_count=1.03
# x=31, bin=11111, fit=961, prob=0.258, exp_count=1.03
# x=31, bin=11111, fit=961, prob=0.258, exp_count=1.03
#
# Generation 8
# x=27, bin=11011, fit=729, prob=0.229, exp_count=0.92
# x=31, bin=11111, fit=961, prob=0.302, exp_count=1.21
# x=31, bin=11111, fit=961, prob=0.302, exp_count=1.21
# x=23, bin=10111, fit=529, prob=0.166, exp_count=0.67
#
# Generation 9
# x=15, bin=01111, fit=225, prob=0.104, exp_count=0.42
# x=31, bin=11111, fit=961, prob=0.446, exp_count=1.78
# x=31, bin=11111, fit=961, prob=0.446, exp_count=1.78
# x=3, bin=00011, fit=9, prob=0.004, exp_count=0.02
#
# Generation 10
# x=15, bin=01111, fit=225, prob=0.095, exp_count=0.38
# x=31, bin=11111, fit=961, prob=0.405, exp_count=1.62
# x=15, bin=01111, fit=225, prob=0.095, exp_count=0.38
# x=31, bin=11111, fit=961, prob=0.405, exp_count=1.62
#
# Final Best Solution: 31 11111 fitness= 961
